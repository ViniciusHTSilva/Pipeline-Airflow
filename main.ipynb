# %%
import os
import pandas as pd
from  os.path import join
from datetime import datetime, timedelta
from dotenv import load_dotenv
load_dotenv()


api = os.getenv("API")

# %% [markdown]
# Intervalo de Datas

# %%
data_inicio = datetime.today()
data_fim = data_inicio + timedelta(days=7)

# %% [markdown]
# Formatando as datas

# %%
data_inicio = data_inicio.strftime("%Y-%m-%d")
data_fim = data_fim.strftime("%Y-%m-%d")

# %% [markdown]
# Conectando a API

# %%
City = "SaoPaulo"

url = url = f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{City}/{data_inicio}/{data_fim}?unitGroup=metric&include=days&key={api}&contentType=csv'

# %%
dados = pd.read_csv(url)
dados.head()
# Out:
#                     name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0  São Paulo, SP, Brasil  2026-05-20     19.6     15.0  16.9          19.6
# 1  São Paulo, SP, Brasil  2026-05-21     18.2     13.6  15.5          18.2
# 2  São Paulo, SP, Brasil  2026-05-22     18.7     13.6  15.3          18.7
# 3  São Paulo, SP, Brasil  2026-05-23     17.4     15.1  15.9          17.4
# 4  São Paulo, SP, Brasil  2026-05-24     21.8     15.4  17.7          21.8
#
#    feelslikemin  feelslike   dew  humidity  ...  solarenergy  uvindex  \
# 0          15.0       16.9  15.2      89.7  ...          4.3        3
# 1          13.6       15.5  12.5      82.7  ...          5.9        4
# 2          13.6       15.3  13.0      86.2  ...          7.3        5
# 3          15.1       15.9  15.1      94.9  ...          2.9        2
# 4          15.4       17.7  16.3      91.7  ...         12.7        6
#
#    severerisk              sunrise               sunset  moonphase  \
# ...

# %%
dados.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              8 non-null      str
#  1   datetime          8 non-null      str
#  2   tempmax           8 non-null      float64
#  3   tempmin           8 non-null      float64
#  4   temp              8 non-null      float64
#  5   feelslikemax      8 non-null      float64
#  6   feelslikemin      8 non-null      float64
#  7   feelslike         8 non-null      float64
#  8   dew               8 non-null      float64
#  9   humidity          8 non-null      float64
#  10  precip            8 non-null      float64
#  11  precipprob        8 non-null      int64
#  12  precipcover       8 non-null      float64
#  13  preciptype        8 non-null      str
#  14  snow              8 non-null      int64
#  15  snowdepth         8 non-null      int64
# ...

# %%
file_path = f'/home/vinicius/Documentos/GitHub/pipeline/semana={data_inicio}/'
os.mkdir(file_path)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[45], line 2
#       1 file_path = f'/home/vinicius/Documentos/GitHub/pipeline/semana={data_inicio}/'
# ----> 2 os.mkdir(file_path)
#
# FileExistsError: [Errno 17] File exists: '/home/vinicius/Documentos/GitHub/pipeline/semana=2026-05-20/'

# %%
dados.to_csv(file_path + 'dados.csv')
dados[['datetime', 'tempmin','temp','tempmax']].to_csv(file_path + 'temperature.csv')
dados[['datetime', 'description','icon']].to_csv(file_path + 'condicoes.csv')
